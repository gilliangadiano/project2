# %%
#API_KEY= "AIzaSyBCFgTOhvKA6X3s0sPuVxVR1SucvrFS5tc"
from config import YouTube_KEY
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-efcbe34be317> in <module>()
#       1 #API_KEY= "AIzaSyBCFgTOhvKA6X3s0sPuVxVR1SucvrFS5tc"
# ----> 2 from config import YouTube_KEY
#       3 from datetime import datetime
#
# ModuleNotFoundError: No module named 'config'

# %%
from apiclient.discovery import build

# %%
youtube = build("youtube", "v3", developerKey=YouTube_KEY)

# %%
# Get channel info
res = youtube.search().list(part='snippet', 
                            q='5-Minute Crafts',
                            type='channel').execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/roDsvgHUNQDDcdrIVU13my19uYE"',
#  'nextPageToken': 'CAUQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 19293, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1d5_1Jbi325XTQeqgiWpX66fzYE"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw'},
#    'snippet': {'publishedAt': '2016-11-15T09:25:37.000Z',
#     'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#     'title': '5-Minute Crafts',
#     'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself! OFFICIAL CHANNEL.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-xIpCEoEWz-U/AAAAAAAAAAI/AAAAAAAAAAA/583J6o-KtGc/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-xIpCEoEWz-U/AAAAAAAAAAI/AAAAAAAAAAA/583J6o-KtGc/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-xIpCEoEWz-U/AAAAAAAAAAI/AAAAAAAAAAA/583J6o-KtGc/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': '5-Minute Crafts',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ows-j6u3Xvj7giIyweN1G78R-zw"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC57XAjJ04TY8gNxOWf-Sy0Q'},
#    'snippet': {'publishedAt': '2017-10-30T13:03:19.000Z',
#     'channelId': 'UC57XAjJ04TY8gNxOWf-Sy0Q',
#     'title': '5-Minute Crafts KIDS',
#     'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself! OFFICIAL CHANNEL.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-qNT8lL8VGw4/AAAAAAAAAAI/AAAAAAAAAAA/DMmXci1YJ5U/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-qNT8lL8VGw4/AAAAAAAAAAI/AAAAAAAAAAA/DMmXci1YJ5U/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-qNT8lL8VGw4/AAAAAAAAAAI/AAAAAAAAAAA/DMmXci1YJ5U/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': '5-Minute Crafts KIDS',
#     'liveBroadcastContent': 'upcoming'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ew84OQvjuSLkeO0rsId2WIKc8VU"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC2etEuPIfohP4P53wM0KImA'},
#    'snippet': {'publishedAt': '2018-01-18T08:58:56.000Z',
#     'channelId': 'UC2etEuPIfohP4P53wM0KImA',
#     'title': '5-Minute Crafts GIRLY',
#     'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself! OFFICIAL CHANNEL.',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-CjSVbxtYcuU/AAAAAAAAAAI/AAAAAAAAAAA/-m3lm3X9Y-k/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-CjSVbxtYcuU/AAAAAAAAAAI/AAAAAAAAAAA/-m3lm3X9Y-k/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-CjSVbxtYcuU/AAAAAAAAAAI/AAAAAAAAAAA/-m3lm3X9Y-k/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': '5-Minute Crafts GIRLY',
#     'liveBroadcastContent': 'upcoming'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/FXuEKlVIGzNumFdWR0CMSYsgSS0"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC1SaV8cJ5u5U9iEZS6QRbpg'},
#    'snippet': {'publishedAt': '2019-02-01T09:34:19.000Z',
#     'channelId': 'UC1SaV8cJ5u5U9iEZS6QRbpg',
#     'title': '5-Minute Crafts TEENS',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-OWbzh2XiEdg/AAAAAAAAAAI/AAAAAAAAAAA/TXJ-9OMy4Wg/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-OWbzh2XiEdg/AAAAAAAAAAI/AAAAAAAAAAA/TXJ-9OMy4Wg/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-OWbzh2XiEdg/AAAAAAAAAAI/AAAAAAAAAAA/TXJ-9OMy4Wg/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': '5-Minute Crafts TEENS',
#     'liveBroadcastContent': 'none'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/lvH8j3Sqn2tXfRAE462VM_beSvQ"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UC99JadZaqowmJR2z6syIZyw'},
#    'snippet': {'publishedAt': '2018-05-04T09:41:42.000Z',
#     'channelId': 'UC99JadZaqowmJR2z6syIZyw',
#     'title': '5 मिनट शिल्',
#     'description': '5-minute crafts© (indian) खुद करने वाले मज़ेदार प्रोजेक्ट्स, क्राफ्ट्स, खुद करके ख़ुशी का...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-mgFAujAy3O8/AAAAAAAAAAI/AAAAAAAAAAA/OyZfKdFE4l4/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-mgFAujAy3O8/AAAAAAAAAAI/AAAAAAAAAAA/OyZfKdFE4l4/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-mgFAujAy3O8/AAAAAAAAAAI/AAAAAAAAAAA/OyZfKdFE4l4/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'channelTitle': '5 मिनट शिल्',
#     'liveBroadcastContent': 'none'}}]}

# %%
# Channel ID
channelID = res['items'][0]['snippet']['channelId']
channelID
# Out:
# 'UC295-Dw_tDNtZXFeAPAW6Aw'

# %%
# Channel description
res['items'][0]['snippet']['description']
# Out:
# 'Fun diy-projects, crafts, experience the joy of doing it yourself! OFFICIAL CHANNEL.'

# %%
# Channel profile pic URL
res['items'][0]['snippet']['thumbnails']['medium']['url']
# Out:
# 'https://yt3.ggpht.com/-xIpCEoEWz-U/AAAAAAAAAAI/AAAAAAAAAAA/583J6o-KtGc/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'

# %%
# Get channel country & published date
res = youtube.channels().list(id=channelID,
                              part='snippet').execute()
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PGCzPHZ6uaW3R6vNl_Lyigk9N5Q"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/l_7v5U8AXls5HgPUBmqMsMoYPLQ"',
#    'id': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'snippet': {'title': '5-Minute Crafts',
#     'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself!\nOFFICIAL CHANNEL.',
#     'publishedAt': '2016-11-15T09:25:37.000Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s88-mo-c-c0xffffffff-rj-k-no',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s240-mo-c-c0xffffffff-rj-k-no',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s800-mo-c-c0xffffffff-rj-k-no',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': '5-Minute Crafts',
#      'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself!\nOFFICIAL CHANNEL.'},
#     'country': 'US'}}]}

# %%
res['items'][0]['snippet']
# Out:
# {'title': '5-Minute Crafts',
#  'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself!\nOFFICIAL CHANNEL.',
#  'publishedAt': '2016-11-15T09:25:37.000Z',
#  'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s88-mo-c-c0xffffffff-rj-k-no',
#    'width': 88,
#    'height': 88},
#   'medium': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s240-mo-c-c0xffffffff-rj-k-no',
#    'width': 240,
#    'height': 240},
#   'high': {'url': 'https://yt3.ggpht.com/a-/AAuE7mDjtp5FjhtHhnIlpaL0UKc0zKLflRngZgLxAQ=s800-mo-c-c0xffffffff-rj-k-no',
#    'width': 800,
#    'height': 800}},
#  'localized': {'title': '5-Minute Crafts',
#   'description': 'Fun diy-projects, crafts, experience the joy of doing it yourself!\nOFFICIAL CHANNEL.'},
#  'country': 'US'}

# %%
publishedAt = res['items'][0]['snippet']['publishedAt']
publishedAt
# Out:
# '2016-11-15T09:25:37.000Z'

# %%
import dateutil.parser as parser

# %%
year = parser.parse(res['items'][0]['snippet']['publishedAt']).year 
month = parser.parse(res['items'][0]['snippet']['publishedAt']).month
day = parser.parse(res['items'][0]['snippet']['publishedAt']).day

print(f"year: {year}, month: {month}, day: {day}")
# Out:
# year: 2016, month: 11, day: 15

# %%
country = res['items'][0]['snippet']['country']
country
# Out:
# 'US'

# %%
# Get Channel statistics (view count, subscriber count, videoCount)

res = youtube.channels().list(id=channelID,
                              part='statistics').execute()

# %%
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/NSBpSxfW0SYtkcXsHmYl5L-dBic"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nIO370zFxENgUTEXx8d9r0IC-MM"',
#    'id': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'statistics': {'viewCount': '12247105313',
#     'commentCount': '0',
#     'subscriberCount': '49557984',
#     'hiddenSubscriberCount': False,
#     'videoCount': '2717'}}]}

# %%
channel_stats = res['items'][0]['statistics']
channel_stats
# Out:
# {'viewCount': '12247105313',
#  'commentCount': '0',
#  'subscriberCount': '49557984',
#  'hiddenSubscriberCount': False,
#  'videoCount': '2717'}

# %%
# Channel Topic detail
res = youtube.channels().list(id=channelID,
                              part='topicDetails').execute()
res
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2Bqu2Ko5E2DitmPeo7xCaMS5b68"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Y9MP6V1wcNP4c7ofQM38b59f5BI"',
#    'id': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'topicDetails': {'topicIds': ['/m/03glg', '/m/019_rr'],
#     'topicCategories': ['https://en.wikipedia.org/wiki/Hobby',
#      'https://en.wikipedia.org/wiki/Lifestyle_(sociology)']}}]}

# %%
# Banner Image
res = youtube.channels().list(id=channelID,
                              part="brandingSettings").execute()

# %%
res["items"][0]['brandingSettings']['image']['bannerImageUrl']
# Out:
# 'https://yt3.ggpht.com/CTGN_jASBWV_U8nm0u_VJreGs5KIrA4E-NArFiAt1CAwtzGzakPoYE2SrzpPlLulQKDaaWZHoA=w1060-fcrop64=1,00005a57ffffa5a8-nd-c0xffffffff-rj-k-no'

# %%
# Get ALL videos from Channel

# %%
youtube.channels().list(id=channelID,
                        part='contentDetails').execute()
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/14nyDKis1LAFRRlklyaNb2VxFCs"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IfXXEeoLG5uzrGcRy6lUGkvp4LQ"',
#    'id': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'contentDetails': {'relatedPlaylists': {'likes': 'LL295-Dw_tDNtZXFeAPAW6Aw',
#      'uploads': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
uploadID = playlist['items'][0]['contentDetails']['relatedPlaylists']['uploads']
uploadID
# Out:
# 'UU295-Dw_tDNtZXFeAPAW6Aw'

# %%
num = youtube.playlistItems().list(playlistId=uploadID,
                                  part='snippet').execute()
total_videos = num['pageInfo']['totalResults']
total_videos
# Out:
# 2717

# %%
# Get DESCRIPTION (Date & Description) on ALL videos from a channel from "Uploads"
def get_channel_videos(channel_id):
    
    # get Uploads playlist id
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos

# %%
# pass in channel ID
videos = get_channel_videos(channelID)

# %%
videos[:10]
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fRV2KqZyATGxdcEH9EakoaZhUv0"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LjRxNGxlZmE0UGxv',
#   'snippet': {'publishedAt': '2019-02-15T08:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '22 CEMENT AND CLAY DIY IDEAS',
#    'description': 'COOL CRAFTS FROM CEMENT\n\nWe love making crafts from different materials. Today you will find a collection of ideas from polymet clay and concrete. Sometimes, cement and concrete are overlooked as people think that these materials are hard to use. Believe or not, but cement and concrete are one of the best materials for crafting. And both materials are quite simple to use. You can make a whole collection of decorative items like vases, planters and even furniture. Let’s make together a trivet for your kettle using silicone mold, drinking straws, and cement. Watch our full tutorial in this video. Do you need to buy a stool? You can make it at home and this project is pretty easy. You will need a bucket, three wooden legs, concrete and sticky tape. Mix cement according to the instruction on the package in the bucket. Once the concrete is settled, place legs inside and secure them using sticky tape. Wait till the concrete has fully hardened take the stool out of a bucket. Now you have a perfect stool, also, you can paint it in any color you like. \nYou can make small concrete letters for a Birthday or big concrete letters to decorate home or office. You will need cardboard to make a mold and wrap them in a few layers of tape to avoid a leak. Pour concrete mix inside the letters and let dry. Remove the cardboard and enjoy! You can also use concrete letters as bookends.\nOne more cool material to create is polymer clay. You can create different handmade accessories like cute bowls for jewelry, a holder for pencils, a dish for a soap bar. \n\nTIMESTAMPS:\n00:13 Concrete vase\n02:28 Cement animals\n04:24 Handmade candle holders\n05:16 Concrete bookends\n05:46 Polymer clay crafts\n13:12 Bracelet with real flowers inside\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4q4lefa4Plo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4q4lefa4Plo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4q4lefa4Plo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/4q4lefa4Plo/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/4q4lefa4Plo/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '4q4lefa4Plo'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/jD482Fup0vcPDynjllG6i0DqDXw"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LlRQZGxDRm9weGMw',
#   'snippet': {'publishedAt': '2019-02-15T13:30:01.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '25 AWESOME AND CHEAP HACKS FOR YOUR BEAUTY',
#    'description': 'MUST KNOW BEAUTY TIPS\n\nTry our cool beauty tricks we share today: if your belly doesn’t ready for the summer, try contouring makeup technique; get rid of flyaways using a toothbrush and hairspray; make a makeup remover at home from an old highlighter.\nHaving healthy teeth requires a lot of effort and is a vital part of everyday routine. Our helpful lifehacks will help you to prevent different problems. \nTry our natural recipes of teeth whitening. We use baking soda and lemon juice activated carbon and water of even kiwi and cucumber! Here is a simple recipe: crush the strawberry and mix it with toothpaste and spread the mixture on your teeth using a toothbrush. Also, you can crush kiwis and cucumber and use a toothbrush to clean your teeth. Repeat for 7 days. One more cool hack on how to quickly whiten your teeth. Rub the inside of a banana peel on your teeth. Besides, this hack will save you a lot of money. \nBad breath might be a sign of health problems like gastrointestinal problems, liver problems, problems with lungs, throat infection and more. There are few ways to check if you have an unpleasant smell in your mouth. Check our video and find how to test your breath using a spoon or a glass. Moreover, we share reasons of unpleasant smell: the wrong toothbrush; you don’t brush your teeth after a meal; incorrect diet and more. If you tried all the ways to get rid of bad breath and there is no result it’s time to see a doctor.\nDon’t forget to eat fresh crunchy vegetables like carrots, fruits that contain acids – oranges, pineapples, strawberries, nuts to feed the bone tissue. Always drink water as water balance is highly important and also it washes away food and strengthens the enamel.\n\nTIMESTAMPS:\n00:42 Belly contouring\n01:53 Makeup remover marker\n03:16 Whiten your teeth at home\n04:19 Use the banana peel to whiten teeth\n04:45 Check your breath\n07:25 The correct ways to clean your teeth\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TPdlCFopxc0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/TPdlCFopxc0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/TPdlCFopxc0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/TPdlCFopxc0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/TPdlCFopxc0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'TPdlCFopxc0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vIvJ2Qwga-q8WN8DUfnrJ2At7Uo"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LkVSZTZHQkY2d1JN',
#   'snippet': {'publishedAt': '2019-02-14T13:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '27 COOL HACKS THAT WILL KNOCK YOUR SOCKS OFF',
#    'description': "CRAZY WAYS TO USE ORDINARY THINGS\n\nThis video is a collection of lifehacks how multifunctional ordinary thing could be. Every girl has panty liners in her bag. Panty liners have a lot of different purposes! It’s an amazingly versatile product and you will be surprised how useful they could be:\n-    If you forgot flip-flips use panty liners instead\n-    Makeup wipes are rather expensive and to cut costs, you can use panty liners. Pour micellar water on a panty liner and use it to remove makeup.\n-    Panty liners are perfect to absorb sweat. Stick panty liners to your bra and it will be an absorbent shield for the whole day\n-    Pour water on the sanitary pad and place in freezer. Use it as an ice pack if you have bruises\n-    Stick sanitary pads to your shirt to avoid sweat stains\n-    Accepted that leggings can be worn as pants but camel toe looks embarrassing. Watch our video and learn how to prevent camel toe, no matter where you are or what you're wearing.\nOne more incredible collection of ideas is lifehacks with scotch tape. It’s a very multifunctional item that could be used not only to fix a lot of things but also to make your Instagram photos better. Wait what? Yes, if you want to look skinnier on photos, use sticky tape to make your belly look perfect. Replicate fingerprints using sticky tape. Cover a finger with red lipstick and stick scotch tape. There is a cool way to make a feather-shaped out of scotch tape earrings just in 5 minutes. Use sticky tape to create a cool manicure design idea. \nYou will be totally shocked by the weird ways to cook a steak. Use toaster, iron and even a chicken to cook the best steak ever! Let’s cook a steak using an iron – wrap meat in a piece of foil and place a hot iron on it for 5 minutes from every side.\n\nTIMESTAMPS:\n00:09 Hot glue gun crafts\n01:41 DIY Bubble machine\n03:15 Panty liner crazy uses\n12:47 Crazy water filter idea\n14:00 Weird ways to cook a steak\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ERe6GBF6wRM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ERe6GBF6wRM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ERe6GBF6wRM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ERe6GBF6wRM/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/ERe6GBF6wRM/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ERe6GBF6wRM'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oDAuq2wP2AuMt5-6mJlgur5IJfs"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LnI3dWtVbE9IYzlz',
#   'snippet': {'publishedAt': '2019-02-16T08:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '28 AWESOME PHONE HACKS',
#    'description': 'INEXPENSIVE DIY PHONE CASES\n\nUsually, phone cases used for protection but most of the people use phone cases to personalize phones. We love phones because they play a great role in our life. We may say that the phone is a perfect representation of you as a person. Phone case may show if you are a dreamer, artist or love minimalist stylish phone cases. Sometimes phone cases could be incredibly expensive in cell phone stores. Luckily, you can make your own phone case at home for little money. Check out our cool and easy craft projects that will require minimum effort.\nCheck out these cool phone lifehacks:\n-    Create DIY tripod using a coke bottle and rubber bands\n-    Use a balloon to make a phone case. Blow your balloon as big as your smartphone, put your phone on the center of the balloon and slowly deflate the balloon. Voila!\n-    Use the eraser to clean a smartphone screen\n-    Watch our tutorial on how to make a phone case with a hot glue gun. Wrap your smartphone with cellophane and easily make a phone case\n-    The long cord is not comfortable at all and we have a trick on how to transform straight cable into a coiled one. It will take less place and gets less tangled and looks a whole lot better.\n-    Change your phone background to a photo of your name and an emergency contact number in case you lose your phone\n-    If you love to be chic - decorate your phone case with feathers, laces, jewelry and more!\n-    Transform your boring phone case cool thermal case in just three easy steps. Cover the plain phone case with white paint, add a layer of yellow nail polish and the last layer will be a clear color-changing nail polish \n-    Make a smartphone projector out of a shoe box. You will need a magnifying glass, shoe box, and binder clip \n\nTIMESTAMPS:\n00:10 Hot glue phone case\n00:36 DIY Flashlight diffuser\n01:31 Balloon phone case\n04:22 Thermal phone case\n09:00 Inexpensive phone holder\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/r7ukUlOHc9s/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/r7ukUlOHc9s/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/r7ukUlOHc9s/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/r7ukUlOHc9s/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/r7ukUlOHc9s/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'r7ukUlOHc9s'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/jW0iuEtVnqWxcl6duSv7qTT9n0k"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LjgxaERWaGhLUWww',
#   'snippet': {'publishedAt': '2019-02-13T13:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '25 AWESOME HACKS YOU SHOULD TRY RIGHT NOW',
#    'description': "LIFEHACKS EVERYBODY SHOULD KNOW\n\nCheck out cool kitchen hacks that will ease your life. You will learn how to cook faster, learn perfect solutions for typical kitchen problems. Besides, you will find cool camping hacks that will help you to spend your time in the wild the in the most comfortable way possible.\nEverybody loves to eat chips while watching the favorite show but your hands become dirty. If you are too lazy to wash hands, use chopsticks. We have more ideas on how to comfortably eat chips: roll the chips bag from the bottom to turn it into a bowl. Learn how to eat every last bite without getting crumbs everywhere. Insert a sheet of paper in Pringles can to eat chips comfortably. You will find a shocking recipe of giant chips that you can use to prank your friends. \nWatermelon is sure is the best fruit! That’s why we prepared surprising ways to cut and peed watermelons, how to make delicious desserts and even watermelon bomb! You will learn the ways how to quickly cut and serve a watermelon in an unusual way. One more cool idea is to make a watermelon no-bake cake. To make this simple recipe, cut off a watermelon's rind then cover in whipped cream and decorate with berries. This is the best dessert for a summer party. One more cool recipe is Cola watermelon.\nHere are some genius camping lifehacks:\n-    Make a portable water filter. You will need a plastic bottle, cheesecloth, rubber bands, stones, sand, and charcoal\n-    make DIY BBQ grill from old can and soda can\n-    Use corn chips as Firestarter\n-    Learn how to light a fire using AA battery and foil\n\nTIMESTAMPS:\n00:14 Cola watermelon\n01:48 Watermelon bomb\n04:00 Use chopsticks to eat chips\n04:41 Giant chips prank\n07:34 Camping hacks\n\n\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/81hDVhhKQl0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/81hDVhhKQl0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/81hDVhhKQl0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/81hDVhhKQl0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/81hDVhhKQl0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '81hDVhhKQl0'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PeEalD-igOEETrqTLqUj7DOfNFI"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LnQ5aTM0WnYyOGxZ',
#   'snippet': {'publishedAt': '2019-02-14T00:30:02.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '31 SMART KITCHEN TIPS',
#    'description': 'COOK LIKE A PRO\n\nWe prepared a surprising way to reuse a plastic bottle. If you love kebabs, try to make a real kebab machine! And it’s not a joke! Take a small plastic bottle, a soda can, and an elbow-shaped piece of PVC pipe and skewers to make perfect kebabs. Cut off the top of the plastic bottle. Make a hole in the center of the pipe and connect the pipe to the bottle. This cool project is inexpensive and won’t take much effort.\nYou will find more ideas on how to reuse plastic bottles: make cookie cutters, separate egg whites or yolks using cola plastic bottle, use a plastic bottle to decorate the cake and more!\nYou will totally love our carving ideas. We will teach you how to peel fruits like a pro! Everybody knows that it takes a lot of time and effort to cut potatoes before making fries. Learn how to do it really fast! Simply cut a potato using an apple core slicer to make perfect homemade fries!\nFind more life-changing kitchen hacks:\n-    Freeze apple to make juice easily\n-    Cook fat-free bacon using aluminum foil\n-    Prepare homemade quick jam\n-    Check out fast ways to peel grapefruits\n-    Learn a super easy way to cut eggs – using a grill rack\n-    Watch our video and find out how to take a cheap syringe and turn it into a super useful kitchen tool\n-    Check out beautiful ways to decorate dishes\nWe love desserts and you can create a culinary masterpiece at home! You will find a lot of awesome pastry ideas that require minimum effort. Watch our tutorials and find numerous ways to fold the dough and different stuffing ideas.\n\n TIMESTAMPS:\n00:09 Clever way to cut a cake\n04:40 Homemade jam\n10:28 Quick way to cut a potato\n12:26 DIY Kebab machine\n19:54 Pastry idea\n\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t9i34Zv28lY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/t9i34Zv28lY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/t9i34Zv28lY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/t9i34Zv28lY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/t9i34Zv28lY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 5,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 't9i34Zv28lY'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zmctho4kanHX9lCGZv40-_G0lBo"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LnN4YUhaeGpoTlRv',
#   'snippet': {'publishedAt': '2019-02-16T00:30:03.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '25 GREAT CLOTHING HACKS',
#    'description': 'CLOTHING HACKS EVERYONE NEEDS TO KNOW\n\nToday we have a collection of golden clothing hacks to keep wardrobe organized and different ideas on how to reuse and revamp old clothes!\nOrganizing home is not an easy task to do especially if you need to do it in a fast and clever way. Is your wardrobe in order? Organize your clothes using our time and space-saving tips. The main idea is the right techniques for folding every piece of clothing in order to maximize closet space. Watch our video to learn how to effectively store your underwear. Fold panties to find them easily in the drawer. Moreover, you will find effective ideas about how to fold jeans and hoodies when you are going to travel. One more clever idea is to use vacuum packing. Moreover, check out a collection of brilliant ways how to fold clothes properly in 30 seconds. Learn how to fold things for a trip in order to avoid wrinkles and folds. \nDo you have a lot of old t-shirts and jeans that you want to throw away? Stop! The answer is recycling! Do not spend money on new clothes, try to do something special with the old one. Upgrade your boring denim jacket with laces. Grab your hot glue gun and scissors and chop-chop! If you are tired of your old short and want something new for summer, re-purpose your old tight shorts by using a piece of lace fabric. Follow our easy step-by-step sewing tutorial to give your shorts a new fashionable look.\nOne more cool idea of how to redecorate your clothes is to add embroidery. Learn how to make really cool embroidery hearts, stars, ladybirds and even an awesome rainbow!\n\nTIMESTAMPS:\n00:15 Perfect folding techniques\n01:35 Folding board\n06:21 Jeans shopping bag\n13:13 DIY sewing kit\n19:58 Embroidery ideas\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sxaHZxjhNTo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/sxaHZxjhNTo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/sxaHZxjhNTo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/sxaHZxjhNTo/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/sxaHZxjhNTo/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 6,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'sxaHZxjhNTo'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wGzwXept2e81UEMnsaG09eiYmMM"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LldkaGpsd3lrSVZz',
#   'snippet': {'publishedAt': '2019-02-11T19:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '23 LIFE HACKS FOR THE BEST PARTY OF THE YEAR',
#    'description': 'AWESOME PARTY HACKS\n\nNo matter what kind of a party you love – outdoor or indoor, we prepared a cool collection for an awesome party. Let’s start from decorations ideas. Balloons are the best decoration items because they are very cheap and you can create a fairy atmosphere easily. Firstly, you need to choose the party theme and the colors you love. Everything depends on your imagination and taste. You can make bubble balloons that look so cool! The main idea of these balloons is to put a smaller balloon inside a big one. You will need chopsticks and 2 balloons (the small one and the bigger one). Insert one end of a chopstick into a smaller balloon. After that carefully insert a small balloon with chopstick inside the larger one. Remove the chopstick and inflate smaller balloon firstly. After that inflate the bigger one and knot both balloons. Moreover, you can create different decorative elements and toys out of balloons such as flowers, animals, hearts and a lot more. Did you know that balloons have more than one function? Yes, we have a surprising idea – freeze balloons with water inside to keep your drinks cold for the whole evening. Besides, you can choose any color that will suit the theme of your party.\nIf you want to buy a disco ball, don’t do that! Watch our video and make it with your own hands. Find old CDs you don’t need anymore and cut them in small squares using scissors. Take a clear ornament ball and stick squares to the ball using a hot glue gun.\nAs a bonus, you will find a lot of watermelon lifehacks: how to quickly cut and serve a watermelon in a surprising way, watermelon no-bake cake and Cola watermelon dessert. \n\nTIMESTAMPS:\n00:23 Clever way to warm up pizza\n00:35 Bubble balloons\n02:22 Watermelon party ideas\n02:25 Cola watermelon\n04:00 Watermelon bomb\n07:44 DIY Disco ball\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WdhjlwykIVs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/WdhjlwykIVs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/WdhjlwykIVs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/WdhjlwykIVs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/WdhjlwykIVs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 7,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'WdhjlwykIVs'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fLsY5ZW3bf7aYK_D_TqzkgSLVZY"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3LndTRmpja21mRlFR',
#   'snippet': {'publishedAt': '2019-02-13T00:30:00.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': '25 SIMPLE BEAUTY HACKS YOU CAN EASILY REPEAT',
#    'description': 'FACIAL MASKS TO REJUVENATE YOUR SKIN\n\nEvery girl wants to look as good as possible and without spending hours in front of the mirror. We are ready to help you to save your time and help you to look gorgeous. Follow our tips that will make your skin, hair routine much faster and easier.\nTurmeric has been used for centuries in Asia as a medical herb. But a small number of people know that turmeric is a great beauty product and ingredient for facial and hair masks. If we talk about skin care, turmeric is used to brighten the skin. Turmeric is full of antioxidants, is used to exfoliate skin, improves it’s texture and reduce pigmentation. If you want to look fresh and shining in the morning, try our mask for pale skin - mix yogurt, turmeric, rice flour, and honey. Apply for 20 minutes and enjoy the result. Dry and chapped lips is a great problem in winter as it’s cold outside and lips skin is damaged by cold. Don’t forget to exfoliate your lips using our natural and cheap scrub. Mix need sugar, turmeric, and honey. Carefully massage your lips for a minute and the problem is sold! One perfect mask we share is a mask for oily skin. To prepare this mask you will need sandalwood powder, orange juice, turmeric. Moreover, turmeric has an antibacterial effect and heals minor burns: mix turmeric with aloe vera and apply the mixture. \nAlso, you will find a selection of manicure hacks. Don’t forget to take care of your nail. Try our easy recipe hoe to make your nails much healthier: Melt some wax in a bowl, let cool a bit. Place your fingers inside the bowl for few seconds and after that immediately place fingers in a bowl with cold water. Remove the wax. Repeat this procedure during the week and enjoy the result.\n\nTIMESTAMPS:\n00:13 Creative manicure idea\n02:01 Use wax for your nails\n03:27 Rainbow French manicure\n06:19 Turmeric for pale skin\n08:28 Facial mask for oily skin\n10:11 Homemade sugaring paste recipe\n\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wSFjckmfFQQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wSFjckmfFQQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wSFjckmfFQQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/wSFjckmfFQQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/wSFjckmfFQQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 8,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'wSFjckmfFQQ'}}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rBGe0lqW6tbJoZs6gmdSpM65Lw8"',
#   'id': 'VVUyOTUtRHdfdEROdFpYRmVBUEFXNkF3Ll9XVTdJY3hxdmQw',
#   'snippet': {'publishedAt': '2019-02-13T19:30:01.000Z',
#    'channelId': 'UC295-Dw_tDNtZXFeAPAW6Aw',
#    'title': "14 CUTEST DIYs FOR VALENTINE'S DAY",
#    'description': "IMPRESSIVE DIY VALENTINE’S DAY GIFTS\n\nValentine’s is coming and it’s time to prepare for this romantic holiday. Do you want to make a cute gift to express your love? DIY gifts that come from the heart are the best way to please the one you love. We share affordable gift ideas that are super simple to make. You will find tutorials on how to make greeting cards, delicious sweet gifts, and romantic breakfast ideas to express your love on February 14. \nFind easy and wonderful ways of making cards by your own hands. Creative and cute card from the heart is always a good gift that will cost a penny. Grab your scissors, color paper, markers, and glue and start creating! In this video, there a number of ways how to make DIY greeting cards. The first idea is really cool - color-changing DIY greeting card. Supplies you will need a red and black marker, a piece of transparent plastic and color paper. Watch the full tutorial! One more incredible idea is DIY scratch cards. We are big fans of scratch-off cards! These cards are suitable for different occasions – Birthdays, Valentine's Day Mother's Day and other holidays. Print your card design (or use a template) onto a sheet of paper and cut out with scissors. Write the gift options into the hearts. Cover the hearts with soap and then cover with the acrylic paint using a brush. Let dry. Remember that the card means so much more when made with your own hands! Moreover, you can make delicious DIY sweets to melt your boyfriend’s heart. Take a heart-shaped silicone mold and make coffee jellies that are really tasty. \n\nTIMESTAMPS:\n02:01 Cool greeting cards\n04:50 Color-changing DIY card\n05:50 DIY scratch cards\n08:18 Coffee heart jelly\n11:51 Ideas for a romantic breakfast\n\n\n----------------------------------------------------------------------------------------\nOur Social Media:\n\nFacebook: https://www.facebook.com/5min.crafts/\nInstagram: https://www.instagram.com/5.min.crafts/\nTwitter: https://twitter.com/5m_crafts\n\nSubscribe to 5-Minute Crafts GIRLY: https://goo.gl/fWbJqz\nSubscribe to 5-Minute Crafts KIDS: https://goo.gl/PEuLVt\nSubscribe to 5-Minute Crafts MEN: http://bit.ly/2S69VUG\n\nThe Bright Side of Youtube: https://goo.gl/rQTJZz\n\n----------------------------------------------------------------------------------------\nFor more videos and articles visit:\nhttp://www.brightside.me\n\nMusic by Epidemic Sound: https://www.epidemicsound.com/",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_WU7Icxqvd0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_WU7Icxqvd0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_WU7Icxqvd0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/_WU7Icxqvd0/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': '5-Minute Crafts',
#    'playlistId': 'UU295-Dw_tDNtZXFeAPAW6Aw',
#    'position': 9,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '_WU7Icxqvd0'}}}]

# %%
len(videos)
# Out:
# 2723

# %%
# Get video statistics

# 1. Get video ID
v_id = videos[0]['snippet']['resourceId']['videoId']
v_id
# Out:
# '4q4lefa4Plo'

# %%
# 2. Get video stats by ID
v_stats = youtube.videos().list(id=v_id,
                               part='statistics').execute()
v_stats['items']
# Out:
# [{'kind': 'youtube#video',
#   'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/gR936W7NL9jrOGNMFvcMTFVZug8"',
#   'id': '4q4lefa4Plo',
#   'statistics': {'viewCount': '1350749',
#    'likeCount': '15477',
#    'dislikeCount': '1571',
#    'favoriteCount': '0',
#    'commentCount': '891'}}]

# %%
# 3. Pass video IDs as a list 

# get a list of all video ids from videos
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
video_ids[:10]
len(video_ids)
# Out:
# 2723

# %%
def get_videos_stats(video_ids):
    stats = []
    for i in range(0, len(video_ids), 50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
        
    return stats

# %%
videos_stats = get_video_stats(video_ids)

# %%
len(videos_stats)
# Out:
# 55

# %%
videos_stats
# Out:
# [[{'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/muV1HXWlEk6GKvSBsnd_wQzH4Q0"',
#    'id': '4q4lefa4Plo',
#    'statistics': {'viewCount': '1353597',
#     'likeCount': '15494',
#     'dislikeCount': '1574',
#     'favoriteCount': '0',
#     'commentCount': '891'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2bGSMep7OicNx8h9jpJOgBcTsl8"',
#    'id': 'TPdlCFopxc0',
#    'statistics': {'viewCount': '367504',
#     'likeCount': '6662',
#     'dislikeCount': '654',
#     'favoriteCount': '0',
#     'commentCount': '632'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/kdKjEuGVZwv7ufWIzDOo4v6wZ2Q"',
#    'id': 'ERe6GBF6wRM',
#    'statistics': {'viewCount': '419440',
#     'likeCount': '4153',
#     'dislikeCount': '502',
#     'favoriteCount': '0',
#     'commentCount': '359'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JWQ9FkDwMyAbPWiUfb1rAO8dDac"',
#    'id': 'r7ukUlOHc9s',
#    'statistics': {'viewCount': '12800',
#     'likeCount': '1534',
#     'dislikeCount': '84',
#     'favoriteCount': '0',
#     'commentCount': '243'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RP2Hl3bCWqKV5od7HBoNW5T4uok"',
#    'id': '81hDVhhKQl0',
#    'statistics': {'viewCount': '704331',
#     'likeCount': '7261',
#     'dislikeCount': '1008',
#     'favoriteCount': '0',
#     'commentCount': '983'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0mkadhUkL37NvwotI0FcqC8d3Lg"',
#    'id': 't9i34Zv28lY',
#    'statistics': {'viewCount': '497179',
#     'likeCount': '5565',
#     'dislikeCount': '478',
#     'favoriteCount': '0',
#     'commentCount': '354'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/VHroL_LN02amAvVyahvnf8n1UF0"',
#    'id': 'sxaHZxjhNTo',
#    'statistics': {'viewCount': '129448',
#     'likeCount': '4403',
#     'dislikeCount': '303',
#     'favoriteCount': '0',
#     'commentCount': '374'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7yKsjEP-CFEwJUYTl0Q-St5ZkaM"',
#    'id': 'WdhjlwykIVs',
#    'statistics': {'viewCount': '1703747',
#     'likeCount': '17008',
#     'dislikeCount': '1777',
#     'favoriteCount': '0',
#     'commentCount': '942'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oaMdSzhY8WRR8DyFO2yJyGKLd8w"',
#    'id': 'wSFjckmfFQQ',
#    'statistics': {'viewCount': '641181',
#     'likeCount': '8628',
#     'dislikeCount': '676',
#     'favoriteCount': '0',
#     'commentCount': '539'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_RZLtxP1JceCUHsAfqugVv2F7wA"',
#    'id': '_WU7Icxqvd0',
#    'statistics': {'viewCount': '264057',
#     'likeCount': '5466',
#     'dislikeCount': '311',
#     'favoriteCount': '0',
#     'commentCount': '446'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Nl30_M7CeF3pnpnLDOqepmlNKk0"',
#    'id': '9yR1sFp7yzA',
#    'statistics': {'viewCount': '651386',
#     'likeCount': '7432',
#     'dislikeCount': '693',
#     'favoriteCount': '0',
#     'commentCount': '555'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/VlyOKfWpEG4mhM9FsU7G9H3bFgk"',
#    'id': 'S9xlTP1vy7M',
#    'statistics': {'viewCount': '442558',
#     'likeCount': '5311',
#     'dislikeCount': '624',
#     'favoriteCount': '0',
#     'commentCount': '525'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/y-GfYcDBZmH5WOXPCEW2fxQA50I"',
#    'id': '9UR62w4alMw',
#    'statistics': {'viewCount': '1792406',
#     'likeCount': '21158',
#     'dislikeCount': '2107',
#     'favoriteCount': '0',
#     'commentCount': '1435'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6YqbHXRQVWXhu4XQTagCtMdZ7y0"',
#    'id': '3YcoUke-MlQ',
#    'statistics': {'viewCount': '7793777',
#     'likeCount': '50735',
#     'dislikeCount': '7614',
#     'favoriteCount': '0',
#     'commentCount': '2430'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/T5dnijyVujVTovJ8uhPgvu9fBXM"',
#    'id': 'UDB3lqBHnCA',
#    'statistics': {'viewCount': '308618',
#     'likeCount': '4424',
#     'dislikeCount': '634',
#     'favoriteCount': '0',
#     'commentCount': '507'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1roO9dHdMJ4JFHU5_xtI0gQ9FQw"',
#    'id': 'VmU4ACZhu88',
#    'statistics': {'viewCount': '727572',
#     'likeCount': '10120',
#     'dislikeCount': '720',
#     'favoriteCount': '0',
#     'commentCount': '700'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/MsozP20C2BmzOdUHcHlQR09NOE0"',
#    'id': 'y2voZ3BH3L0',
#    'statistics': {'viewCount': '716103',
#     'likeCount': '8216',
#     'dislikeCount': '689',
#     'favoriteCount': '0',
#     'commentCount': '496'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_hWF-HKvoz70sJqkH71U1-7uSTk"',
#    'id': '-fH0Y8sp3Kw',
#    'statistics': {'viewCount': '11513678',
#     'likeCount': '112418',
#     'dislikeCount': '12543',
#     'favoriteCount': '0',
#     'commentCount': '3357'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OgDSdW8AfEtBGewoxMgBEkZfFu0"',
#    'id': 'XN4nyQ0AK4k',
#    'statistics': {'viewCount': '462664',
#     'likeCount': '6624',
#     'dislikeCount': '591',
#     'favoriteCount': '0',
#     'commentCount': '840'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/eO95JS7jHYtgON6_JwyUmBJbuoY"',
#    'id': 'q7xiHXMENCQ',
#    'statistics': {'viewCount': '12775611',
#     'likeCount': '102500',
#     'dislikeCount': '15056',
#     'favoriteCount': '0',
#     'commentCount': '2860'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oEcBVR3ojwQkZ8nmaAYdd0Pd3VE"',
#    'id': 'Z0wpkK-QE-Q',
#    'statistics': {'viewCount': '285317',
#     'likeCount': '4528',
#     'dislikeCount': '293',
#     'favoriteCount': '0',
#     'commentCount': '307'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/eVxItBQOfy2_nBgrUk1Wp6bdSB8"',
#    'id': 'T08DMQX3jjE',
#    'statistics': {'viewCount': '1181651',
#     'likeCount': '12964',
#     'dislikeCount': '1334',
#     'favoriteCount': '0',
#     'commentCount': '779'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/93W6PxVedfE5H6iL4rtl0MJDOhU"',
#    'id': 'JPhhzrS23bI',
#    'statistics': {'viewCount': '2865687',
#     'likeCount': '34719',
#     'dislikeCount': '3770',
#     'favoriteCount': '0',
#     'commentCount': '2266'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/YK4kOyJVtAmWou5X1Athcr_5mwM"',
#    'id': 'fV3uGVAPRIU',
#    'statistics': {'viewCount': '472801',
#     'likeCount': '5453',
#     'dislikeCount': '647',
#     'favoriteCount': '0',
#     'commentCount': '519'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/L6cIK6IkEGGTwAj85t6MIhlg71w"',
#    'id': 'E5gj86INoTw',
#    'statistics': {'viewCount': '331350',
#     'likeCount': '3540',
#     'dislikeCount': '459',
#     'favoriteCount': '0',
#     'commentCount': '415'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fhkGgKCTCvGYeEntL5CsvgGIKdI"',
#    'id': 'Yei9EcNOmus',
#    'statistics': {'viewCount': '1339415',
#     'likeCount': '12536',
#     'dislikeCount': '1710',
#     'favoriteCount': '0',
#     'commentCount': '930'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OTlD8Q3l9Rc6yXGiJTnZliOQ7MY"',
#    'id': 'ZPbVtFJYfuU',
#    'statistics': {'viewCount': '273990',
#     'likeCount': '4125',
#     'dislikeCount': '423',
#     'favoriteCount': '0',
#     'commentCount': '535'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/T49tNlDNoyARwnLrtwVzpKZwj1U"',
#    'id': '2b2bf62SQys',
#    'statistics': {'viewCount': '578721',
#     'likeCount': '6770',
#     'dislikeCount': '845',
#     'favoriteCount': '0',
#     'commentCount': '838'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/gwyd6mmVnWEFhbsG4H0jkVmrXbU"',
#    'id': 'uPpAqim4U1w',
#    'statistics': {'viewCount': '215484',
#     'likeCount': '4890',
#     'dislikeCount': '424',
#     'favoriteCount': '0',
#     'commentCount': '422'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/8nMU2hxELAHjNa4i9bUhM7mKkV8"',
#    'id': 'NtZER0XQAks',
#    'statistics': {'viewCount': '278002',
#     'likeCount': '3251',
#     'dislikeCount': '372',
#     'favoriteCount': '0',
#     'commentCount': '401'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ueiPFUKo6zOVCSXPytx23BCrn30"',
#    'id': '_IqH31KJjX8',
#    'statistics': {'viewCount': '508492',
#     'likeCount': '6393',
#     'dislikeCount': '703',
#     'favoriteCount': '0',
#     'commentCount': '858'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/t0oSg62KuFkhFfcI0jr9ITxeHAk"',
#    'id': 'XQnKd92s58s',
#    'statistics': {'viewCount': '518777',
#     'likeCount': '5491',
#     'dislikeCount': '662',
#     'favoriteCount': '0',
#     'commentCount': '575'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/qtpB88Blnr_fhCHOGahMfRKM2cA"',
#    'id': 'Jt8w2x7cjeY',
#    'statistics': {'viewCount': '751316',
#     'likeCount': '6869',
#     'dislikeCount': '1104',
#     'favoriteCount': '0',
#     'commentCount': '1086'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/1XTFXAs8e2Fw8eFKqSy60mxccGc"',
#    'id': '46vBXXHLTDw',
#    'statistics': {'viewCount': '241614',
#     'likeCount': '4561',
#     'dislikeCount': '298',
#     'favoriteCount': '0',
#     'commentCount': '447'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oNOsPF2yIT9N8pXwCJZPHkVmPC0"',
#    'id': 'pcQ8KEH_4GA',
#    'statistics': {'viewCount': '543860',
#     'likeCount': '5924',
#     'dislikeCount': '729',
#     'favoriteCount': '0',
#     'commentCount': '700'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/71Do00Wrh7pSmuabgAEEfEmNZ2A"',
#    'id': 'fWmA0bY4oFU',
#    'statistics': {'viewCount': '403386',
#     'likeCount': '5455',
#     'dislikeCount': '583',
#     'favoriteCount': '0',
#     'commentCount': '537'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yWM_MPO3bRRzM4jN0YgJ6ZRBhh4"',
#    'id': 'XRZdb916rPA',
#    'statistics': {'viewCount': '4436828',
#     'likeCount': '67951',
#     'dislikeCount': '4359',
#     'favoriteCount': '0',
#     'commentCount': '2476'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/WQ3__dvHJnEb_dA4tvYdMWXwMNI"',
#    'id': 'YK79MrREftg',
#    'statistics': {'viewCount': '728212',
#     'likeCount': '17326',
#     'dislikeCount': '767',
#     'favoriteCount': '0',
#     'commentCount': '718'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/i1Pd8JhvVCIuXYJAeqNoua9wuN4"',
#    'id': '4zc6d5MlxPg',
#    'statistics': {'viewCount': '485797',
#     'likeCount': '6403',
#     'dislikeCount': '831',
#     'favoriteCount': '0',
#     'commentCount': '709'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/iTJ2So8wy-Ioa1YvSw5yUaATw2E"',
#    'id': 'uHLNq8kJAKY',
#    'statistics': {'viewCount': '3918095',
#     'likeCount': '40224',
#     'dislikeCount': '4556',
#     'favoriteCount': '0',
#     'commentCount': '2617'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/N0GWG9sDZaNrEM58spxJhhA9GUY"',
#    'id': 'eVGmkwTu7yA',
#    'statistics': {'viewCount': '1309476',
#     'likeCount': '12352',
#     'dislikeCount': '1665',
#     'favoriteCount': '0',
#     'commentCount': '922'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/dDEIsjYs8GnFBYXOgNipH0NZT5w"',
#    'id': '5g4H75koS4Q',
#    'statistics': {'viewCount': '739548',
#     'likeCount': '9567',
#     'dislikeCount': '767',
#     'favoriteCount': '0',
#     'commentCount': '794'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/T9xwpYbwHURzw4T30J3Biwgqvo4"',
#    'id': 'SNfO2r-2XVc',
#    'statistics': {'viewCount': '445854',
#     'likeCount': '6344',
#     'dislikeCount': '621',
#     'favoriteCount': '0',
#     'commentCount': '441'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/cf13bfcX2DymAIHuwyYBaOqsA1M"',
#    'id': 'dZDe5vBk580',
#    'statistics': {'viewCount': '1195992',
#     'likeCount': '9392',
#     'dislikeCount': '1130',
#     'favoriteCount': '0',
#     'commentCount': '854'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/gX49DuK90G7Us3E_CIC6Qget8XM"',
#    'id': 'pM8Bv8k1XCo',
#    'statistics': {'viewCount': '2727814',
#     'likeCount': '34711',
#     'dislikeCount': '2717',
#     'favoriteCount': '0',
#     'commentCount': '1274'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/XS_WcX2s-US98E0bJBlJjnwfdmg"',
#    'id': 'Ysu0m4CVzSI',
#    'statistics': {'viewCount': '612114',
#     'likeCount': '8185',
#     'dislikeCount': '750',
#     'favoriteCount': '0',
#     'commentCount': '606'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nvc-tP9wdm_FCLF_A8ynUdGyKm0"',
#    'id': 'reJer0k_9kU',
#    'statistics': {'viewCount': '1056729',
#     'likeCount': '13109',
#     'dislikeCount': '1935',
#     'favoriteCount': '0',
#     'commentCount': '682'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/n1C9n0-fbgyakACOmOJlHygeJ-M"',
#    'id': 'xgqlx-GZIv0',
#    'statistics': {'viewCount': '2364065',
#     'likeCount': '18589',
#     'dislikeCount': '2570',
#     'favoriteCount': '0',
#     'commentCount': '1430'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rdfMoyanpSvKVJFp8MgsLtiAWBw"',
#    'id': 'EnDGPrhrm9o',
#    'statistics': {'viewCount': '507987',
#     'likeCount': '4409',
#     'dislikeCount': '548',
#     'favoriteCount': '0',
#     'commentCount': '414'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/hT_TR6o7HLEi3kRkviFLI3HnIhU"',
#    'id': 'C0ypH4qKMQM',
#    'statistics': {'viewCount': '759234',
#     'likeCount': '7843',
#     'dislikeCount': '695',
#     'favoriteCount': '0',
#     'commentCount': '679'}}],
#  [{'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/bgZSEMFrvLhO5PLjVD-sglo6GA4"',
#    'id': 'T0ru2xFWIZM',
#    'statistics': {'viewCount': '570410',
#     'likeCount': '7015',
#     'dislikeCount': '647',
#     'favoriteCount': '0',
#     'commentCount': '757'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/B1_rfcjcwerg9Z6MsI01rOF39dQ"',
#    'id': 'o909eJiN-ck',
#    'statistics': {'viewCount': '2008157',
#     'likeCount': '12472',
#     'dislikeCount': '1959',
#     'favoriteCount': '0',
#     'commentCount': '1041'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6k0QiVqIY9Mtylg4_i5wtYNH9Fk"',
#    'id': '3sDNqpTtHdU',
#    'statistics': {'viewCount': '3780609',
#     'likeCount': '22269',
#     'dislikeCount': '5051',
#     'favoriteCount': '0',
#     'commentCount': '1016'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oc8t5pxSVpf0UwNYovfqdnl2jyM"',
#    'id': '19WssVu4Zng',
#    'statistics': {'viewCount': '4121119',
#     'likeCount': '23395',
#     'dislikeCount': '3610',
#     'favoriteCount': '0',
#     'commentCount': '1438'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LIyxjK5_BV-js-57Dkqzl8xh6cQ"',
#    'id': 'WK7GK3ZC3h4',
#    'statistics': {'viewCount': '1261377',
#     'likeCount': '15453',
#     'dislikeCount': '1431',
#     'favoriteCount': '0',
#     'commentCount': '934'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/6aGovXq5It_Qq9EXI_oTELP4tJY"',
#    'id': 'MAzDJY-c7Qg',
#    'statistics': {'viewCount': '7217866',
#     'likeCount': '33652',
#     'dislikeCount': '7376',
#     'favoriteCount': '0',
#     'commentCount': '2579'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/YfTzUYfoSK2u3AHZgs1kVcXtzwQ"',
#    'id': 'McLFQ8sXylA',
#    'statistics': {'viewCount': '550830',
#     'likeCount': '7643',
#     'dislikeCount': '683',
#     'favoriteCount': '0',
#     'commentCount': '692'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/tgB8BrjlFZ6D8-QmZh8-1Zy6TwM"',
#    'id': 'lXEOhNZndbY',
#    'statistics': {'viewCount': '553471',
#     'likeCount': '7206',
#     'dislikeCount': '642',
#     'favoriteCount': '0',
#     'commentCount': '814'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/etcxvK6m-r0xgumuod_b0JxwlcQ"',
#    'id': '1Nxo-HS6Mvo',
#    'statistics': {'viewCount': '359825',
#     'likeCount': '5825',
#     'dislikeCount': '529',
#     'favoriteCount': '0',
#     'commentCount': '635'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OVIRevQc_6l_VUi9YbLMhq-SCfU"',
#    'id': 'aNowqF7LeGs',
#    'statistics': {'viewCount': '2619042',
#     'likeCount': '27932',
#     'dislikeCount': '2109',
#     'favoriteCount': '0',
#     'commentCount': '1099'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/D2Z86KzyP-N7E7RFztoLkdiVQcM"',
#    'id': 'dKvh9S4jGHQ',
#    'statistics': {'viewCount': '522607',
#     'likeCount': '7516',
#     'dislikeCount': '705',
#     'favoriteCount': '0',
#     'commentCount': '639'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/WNkit_NX3oV7Zr7c3-0xEE4-kRM"',
#    'id': 'T8ZpLyhIgNk',
#    'statistics': {'viewCount': '1839110',
#     'likeCount': '13577',
#     'dislikeCount': '1929',
#     'favoriteCount': '0',
#     'commentCount': '802'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/XTAngRaiMP5Kpt-HH0ArFpttJIQ"',
#    'id': '1Ii_OQNxn4g',
#    'statistics': {'viewCount': '997103',
#     'likeCount': '10796',
#     'dislikeCount': '1309',
#     'favoriteCount': '0',
#     'commentCount': '698'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Sh10uV43Mb6Z5ZpUzwaIUzeyOFM"',
#    'id': 'paNmx9xhq_s',
#    'statistics': {'viewCount': '1259263',
#     'likeCount': '12549',
#     'dislikeCount': '1313',
#     'favoriteCount': '0',
#     'commentCount': '825'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nbqCyUGiAc961cEbebBlKl9yfAA"',
#    'id': 'wcSi3Fdklhc',
#    'statistics': {'viewCount': '784772',
#     'likeCount': '9099',
#     'dislikeCount': '795',
#     'favoriteCount': '0',
#     'commentCount': '883'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oR7MeKdNzlnJVg_4sMPK_V4NkQo"',
#    'id': 'JdYPtcny0yM',
#    'statistics': {'viewCount': '386502',
#     'likeCount': '5065',
#     'dislikeCount': '487',
#     'favoriteCount': '0',
#     'commentCount': '269'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/mKsi8Xry09Wn0xXQxdS4BfF1mT8"',
#    'id': 'z7QlVeLhDBE',
#    'statistics': {'viewCount': '747345',
#     'likeCount': '8927',
#     'dislikeCount': '781',
#     'favoriteCount': '0',
#     'commentCount': '615'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5tdgmEtUoTtQN_07IMrl5x4nIN8"',
#    'id': 'SNewlp1Vz58',
#    'statistics': {'viewCount': '11007805',
#     'likeCount': '74468',
#     'dislikeCount': '15173',
#     'favoriteCount': '0',
#     'commentCount': '3004'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/55j-CAmf88jjZoJSOAfc3kNaVOU"',
#    'id': 'gdNcRfbe230',
#    'statistics': {'viewCount': '5742005',
#     'likeCount': '32996',
#     'dislikeCount': '5889',
#     'favoriteCount': '0',
#     'commentCount': '1750'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/sMEzo4YFPXYsrdqTOrKglF8IDFQ"',
#    'id': '4L1_eVKxPp0',
#    'statistics': {'viewCount': '731171',
#     'likeCount': '7580',
#     'dislikeCount': '776',
#     'favoriteCount': '0',
#     'commentCount': '553'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vp9txth0egQny5QAtbyDnPb2kj4"',
#    'id': 'kwO1xFA6BN4',
#    'statistics': {'viewCount': '203483',
#     'likeCount': '3850',
#     'dislikeCount': '471',
#     'favoriteCount': '0',
#     'commentCount': '374'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/hatVErFkN53zO3x9V_tNx_97vfc"',
#    'id': 'Bd_9hhoX5PU',
#    'statistics': {'viewCount': '4380035',
#     'likeCount': '26087',
#     'dislikeCount': '4657',
#     'favoriteCount': '0',
#     'commentCount': '988'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/HBA795_3QCluVdnl7Ej5Qv5iopU"',
#    'id': '01rON5qqlPI',
#    'statistics': {'viewCount': '4474499',
#     'likeCount': '30921',
#     'dislikeCount': '5845',
#     'favoriteCount': '0',
#     'commentCount': '1413'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IntqEKXKUqVkzPK1BXPccK1js-w"',
#    'id': 's8syL0AmLD0',
#    'statistics': {'viewCount': '812915',
#     'likeCount': '8114',
#     'dislikeCount': '744',
#     'favoriteCount': '0',
#     'commentCount': '459'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Jaav2Lj1o-ZZedThTEwsxj2zThM"',
#    'id': 'W15u_OwHnjQ',
#    'statistics': {'viewCount': '477036',
#     'likeCount': '7644',
#     'dislikeCount': '622',
#     'favoriteCount': '0',
#     'commentCount': '575'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3670Jb7XVnP6A8xR7i7tpVt-1x8"',
#    'id': 'oz4mC8HXakE',
#    'statistics': {'viewCount': '3955894',
#     'likeCount': '26544',
#     'dislikeCount': '4105',
#     'favoriteCount': '0',
#     'commentCount': '685'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RmayDsdwKtqPh3m2XNuAKfsIAes"',
#    'id': 'MHhroeoJnl4',
#    'statistics': {'viewCount': '4145394',
#     'likeCount': '26737',
#     'dislikeCount': '3759',
#     'favoriteCount': '0',
#     'commentCount': '1280'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/SF3NxK2CqjOVBwLO_wMX4ZlgW3o"',
#    'id': 'H0Juwabsqow',
#    'statistics': {'viewCount': '2203731',
#     'likeCount': '21758',
#     'dislikeCount': '2887',
#     'favoriteCount': '0',
#     'commentCount': '2135'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RxYuP87ZAAl4HgMErdbvtq8RQE0"',
#    'id': 'uasBhIHh0YU',
#    'statistics': {'viewCount': '3161070',
#     'likeCount': '28947',
#     'dislikeCount': '2860',
#     'favoriteCount': '0',
#     'commentCount': '1587'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/b81tA8TyMZ9yXiZP8aVY5AqyA-Y"',
#    'id': '8WQr81YqD1Q',
#    'statistics': {'viewCount': '686396',
#     'likeCount': '10132',
#     'dislikeCount': '953',
#     'favoriteCount': '0',
#     'commentCount': '670'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Dl8pEUHW4swgptaqeNPqEzmmwtY"',
#    'id': '1a-8zdtFqd8',
#    'statistics': {'viewCount': '1390272',
#     'likeCount': '15901',
#     'dislikeCount': '1883',
#     'favoriteCount': '0',
#     'commentCount': '943'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vmQzuhrLL-Avt0EF8Aj8pQl-8tY"',
#    'id': 'zENg4NWJjDo',
#    'statistics': {'viewCount': '2312317',
#     'likeCount': '17171',
#     'dislikeCount': '2228',
#     'favoriteCount': '0',
#     'commentCount': '971'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2Hf7NxqIJITFR4OR55sfJMxTWXk"',
#    'id': 'pnBFuKGgNJ0',
#    'statistics': {'viewCount': '787715',
#     'likeCount': '6539',
#     'dislikeCount': '908',
#     'favoriteCount': '0',
#     'commentCount': '414'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/AhvYFxU1q3fDlEqya4o5Y5ixYbk"',
#    'id': 'yqoqs3XnjZE',
#    'statistics': {'viewCount': '869056',
#     'likeCount': '9192',
#     'dislikeCount': '1195',
#     'favoriteCount': '0',
#     'commentCount': '619'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3iVLtsHERBWgvi7TBiemHQEFgqE"',
#    'id': 'EzvRZbQ41j8',
#    'statistics': {'viewCount': '2263764',
#     'likeCount': '21336',
#     'dislikeCount': '3127',
#     'favoriteCount': '0',
#     'commentCount': '631'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/kqLxT_RMGjfnhFnR3TlptPTYnrg"',
#    'id': '19hNo_EEnt4',
#    'statistics': {'viewCount': '626385',
#     'likeCount': '7604',
#     'dislikeCount': '768',
#     'favoriteCount': '0',
#     'commentCount': '567'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/tiyeGavn7Y61_0RtiDzPa7mkWjo"',
#    'id': 'U8_suNp4PPU',
#    'statistics': {'viewCount': '494570',
#     'likeCount': '5386',
#     'dislikeCount': '620',
#     'favoriteCount': '0',
#     'commentCount': '413'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/g_rp7-eKJp0Pz4KpDp0fRSHtzW8"',
#    'id': '4rrqc3Skwr8',
#    'statistics': {'viewCount': '782785',
#     'likeCount': '7240',
#     'dislikeCount': '723',
#     'favoriteCount': '0',
#     'commentCount': '600'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/VxDzyCIqRogwF3oknZz26xj0E88"',
#    'id': '8Fauk_-MuQs',
#    'statistics': {'viewCount': '407256',
#     'likeCount': '5413',
#     'dislikeCount': '510',
#     'favoriteCount': '0',
#     'commentCount': '480'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/xpxnnScu2rOUQJsxJrcnzBMrHvg"',
#    'id': 'zxQaYrcjwSc',
#    'statistics': {'viewCount': '502916',
#     'likeCount': '8191',
#     'dislikeCount': '730',
#     'favoriteCount': '0',
#     'commentCount': '513'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/BfWLFgABE98lFr0fwuhgFGmkgMk"',
#    'id': '0XxUB9qkvIA',
#    'statistics': {'viewCount': '606945',
#     'likeCount': '8906',
#     'dislikeCount': '837',
#     'favoriteCount': '0',
#     'commentCount': '939'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/HmYYoJDtNWe5srEbQX-15FQm2S8"',
#    'id': 'BBzGTm_cvcA',
#    'statistics': {'viewCount': '329751',
#     'likeCount': '5183',
#     'dislikeCount': '478',
#     'favoriteCount': '0',
#     'commentCount': '556'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Cw_1Ni2BximqmE20A3DqDlu_f70"',
#    'id': 'V5Q3-SVQ1z0',
#    'statistics': {'viewCount': '351292',
#     'likeCount': '4596',
#     'dislikeCount': '348',
#     'favoriteCount': '0',
#     'commentCount': '357'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/PbYUmBjvqu1FwNvcM2K7n1Y7Fuo"',
#    'id': 'ULQEHlRrn2c',
#    'statistics': {'viewCount': '2041300',
#     'likeCount': '19621',
#     'dislikeCount': '2001',
#     'favoriteCount': '0',
#     'commentCount': '1020'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/J6A6pYYm564uInXUIMz7TPVvTGk"',
#    'id': 'LHC0K83kMBQ',
#    'statistics': {'viewCount': '15828944',
#     'likeCount': '106880',
#     'dislikeCount': '19766',
#     'favoriteCount': '0',
#     'commentCount': '5584'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/hb_tRvIpmKeypz6Ty7vc3_18zfs"',
#    'id': 'lYD9PVIHSPI',
#    'statistics': {'viewCount': '950465',
#     'likeCount': '17498',
#     'dislikeCount': '1063',
#     'favoriteCount': '0',
#     'commentCount': '775'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2Qnm4GUQCH8VLhl6St5-FVwiENg"',
#    'id': 'qcXyRRsWpd0',
#    'statistics': {'viewCount': '2141376',
#     'likeCount': '23206',
#     'dislikeCount': '2358',
#     'favoriteCount': '0',
#     'commentCount': '1600'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/H-8eu86jfPXuB9QaZfy0MesnQxM"',
#    'id': '5G0p3HF5kDA',
#    'statistics': {'viewCount': '661274',
#     'likeCount': '9891',
#     'dislikeCount': '727',
#     'favoriteCount': '0',
#     'commentCount': '639'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/4MkHo32QazqAbSwKNM5dhGKoewU"',
#    'id': 'QagHy-5Jvuc',
#    'statistics': {'viewCount': '3756922',
#     'likeCount': '37443',
#     'dislikeCount': '4391',
#     'favoriteCount': '0',
#     'commentCount': '2409'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/evHbX9fZm1KM_uYYAkj24vJgr0c"',
#    'id': 'jo0ZmgGuNcc',
#    'statistics': {'viewCount': '13885340',
#     'likeCount': '121150',
#     'dislikeCount': '16570',
#     'favoriteCount': '0',
#     'commentCount': '3515'}}],
#  [{'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/33pTrPc_vk9REMXg62YsNHkLy4U"',
#    'id': 'ug25XWXrBcY',
#    'statistics': {'viewCount': '420224',
#     'likeCount': '5676',
#     'dislikeCount': '632',
#     'favoriteCount': '0',
#     'commentCount': '595'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/--ia9Sfe7J_7qoMqxfUx9xk3cBY"',
#    'id': 'V9BITIuc4k8',
#    'statistics': {'viewCount': '336017',
#     'likeCount': '7393',
#     'dislikeCount': '417',
#     'favoriteCount': '0',
#     'commentCount': '506'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/5MZFqgvvHJcpiXzqo9d0xkDoh5A"',
#    'id': '2Prgt_n2mH0',
#    'statistics': {'viewCount': '641571',
#     'likeCount': '8600',
#     'dislikeCount': '868',
#     'favoriteCount': '0',
#     'commentCount': '596'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ORfSRe1aFuLQhh4wkbctl0v5t6A"',
#    'id': 'jqaUcIk-Maw',
#    'statistics': {'viewCount': '966051',
#     'likeCount': '10217',
#     'dislikeCount': '1102',
#     'favoriteCount': '0',
#     'commentCount': '784'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ojz8580Np8DwgWl2zDt_eNzZxsw"',
#    'id': 'yy3u4db54fU',
#    'statistics': {'viewCount': '1112939',
#     'likeCount': '11740',
#     'dislikeCount': '1199',
#     'favoriteCount': '0',
#     'commentCount': '547'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/aaGk2-g1b3VBe4AblJ5qlSLJlY8"',
#    'id': 'zbmsmH__WYg',
#    'statistics': {'viewCount': '4978127',
#     'likeCount': '29365',
#     'dislikeCount': '8987',
#     'favoriteCount': '0',
#     'commentCount': '2460'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fBiXWjcLe7c6Iot-I8d_bwpjbLQ"',
#    'id': 'V0NXPqzGas8',
#    'statistics': {'viewCount': '3569350',
#     'likeCount': '34867',
#     'dislikeCount': '2835',
#     'favoriteCount': '0',
#     'commentCount': '1541'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/eKoBRYmMcIUOzmnvlFUt_mihV7o"',
#    'id': '9CYQMU5Z9Zs',
#    'statistics': {'viewCount': '416347',
#     'likeCount': '6113',
#     'dislikeCount': '550',
#     'favoriteCount': '0',
#     'commentCount': '635'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OAydQP3GTmE5JS4NtcKf2aGMqjI"',
#    'id': 'DBP6sJ-T-lU',
#    'statistics': {'viewCount': '1442262',
#     'likeCount': '15353',
#     'dislikeCount': '1386',
#     'favoriteCount': '0',
#     'commentCount': '779'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LmEytiTltJomssqJusw6cFDk86M"',
#    'id': 'sPR505L3qUU',
#    'statistics': {'viewCount': '7258683',
#     'likeCount': '36322',
#     'dislikeCount': '8242',
#     'favoriteCount': '0',
#     'commentCount': '1545'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fg1ljT0KPjto7J6TgO3ZjyRGoY0"',
#    'id': '4IgXrUystzs',
#    'statistics': {'viewCount': '1381145',
#     'likeCount': '21265',
#     'dislikeCount': '1683',
#     'favoriteCount': '0',
#     'commentCount': '1196'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/tJkxlqhMusnH7_9Pa-M3s0_aNgQ"',
#    'id': 'Q8td9yAZ4gE',
#    'statistics': {'viewCount': '559783',
#     'likeCount': '8326',
#     'dislikeCount': '644',
#     'favoriteCount': '0',
#     'commentCount': '642'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/r6WzO1EcmhChy0gc7qCY_Pvh4_Q"',
#    'id': '2A8f5teXzG0',
#    'statistics': {'viewCount': '805198',
#     'likeCount': '11842',
#     'dislikeCount': '1710',
#     'favoriteCount': '0',
#     'commentCount': '784'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/mbdbbkScC-4GV_CYjFOze0t9jWI"',
#    'id': 'C9XZmwf-nkc',
#    'statistics': {'viewCount': '1901265',
#     'likeCount': '17486',
#     'dislikeCount': '1914',
#     'favoriteCount': '0',
#     'commentCount': '839'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_4desIBScxOYtc_uTlpGlOW_MZM"',
#    'id': 'aFkyTVTejDQ',
#    'statistics': {'viewCount': '588898',
#     'likeCount': '7336',
#     'dislikeCount': '684',
#     'favoriteCount': '0',
#     'commentCount': '607'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TQleCDUTVelII70RxPOCmRIHV3E"',
#    'id': 'xqAoloAGlCE',
#    'statistics': {'viewCount': '6224141',
#     'likeCount': '48773',
#     'dislikeCount': '7731',
#     'favoriteCount': '0',
#     'commentCount': '1948'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LtHPjLMofIsxcUUST5Q5kv-zAqY"',
#    'id': 'acsthaqsOLg',
#    'statistics': {'viewCount': '1678203',
#     'likeCount': '21285',
#     'dislikeCount': '2400',
#     'favoriteCount': '0',
#     'commentCount': '852'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RtdU5xoAXbZFjYJSUP4WjlMysJE"',
#    'id': 'tk6rAGbAjBI',
#    'statistics': {'viewCount': '328588',
#     'likeCount': '5770',
#     'dislikeCount': '521',
#     'favoriteCount': '0',
#     'commentCount': '517'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2_-91fNjCGJlzeHwhg_jZc9Owyc"',
#    'id': 'VgMMNUjDXE8',
#    'statistics': {'viewCount': '253436',
#     'likeCount': '4510',
#     'dislikeCount': '356',
#     'favoriteCount': '0',
#     'commentCount': '375'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Tjr9gACwSdOLRYN8xal1c-mVe5U"',
#    'id': 'XFUbXV90PMk',
#    'statistics': {'viewCount': '3475793',
#     'likeCount': '23905',
#     'dislikeCount': '3148',
#     'favoriteCount': '0',
#     'commentCount': '924'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/p1j82eQcUf_onEaYC6QeMJzRChg"',
#    'id': 'AS_GLsOnguA',
#    'statistics': {'viewCount': '21659044',
#     'likeCount': '156893',
#     'dislikeCount': '20247',
#     'favoriteCount': '0',
#     'commentCount': '8013'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/HjXoA7Xt_dQ5qb_pX1nI9iwIUds"',
#    'id': 'SeaZ5trUNfs',
#    'statistics': {'viewCount': '649871',
#     'likeCount': '6501',
#     'dislikeCount': '841',
#     'favoriteCount': '0',
#     'commentCount': '642'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/UgNEF1l97JLjyrX0iq_7-b1O2lY"',
#    'id': 'qs6Ogtz86e4',
#    'statistics': {'viewCount': '624213',
#     'likeCount': '8098',
#     'dislikeCount': '771',
#     'favoriteCount': '0',
#     'commentCount': '648'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/uqz7EeA5WI4WetvBj2ULNgAMRSg"',
#    'id': 'guxSUgaKnJA',
#    'statistics': {'viewCount': '334791',
#     'likeCount': '4759',
#     'dislikeCount': '389',
#     'favoriteCount': '0',
#     'commentCount': '374'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/iixbIBD9QkutAhiBINgvgRauXMU"',
#    'id': 'cswlPkdY-oI',
#    'statistics': {'viewCount': '768301',
#     'likeCount': '11068',
#     'dislikeCount': '1012',
#     'favoriteCount': '0',
#     'commentCount': '856'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/XZou_NbZDk59CiTElGMkrg1ToZg"',
#    'id': 'Lvsz20bIjNU',
#    'statistics': {'viewCount': '452799',
#     'likeCount': '6491',
#     'dislikeCount': '596',
#     'favoriteCount': '0',
#     'commentCount': '460'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/aJPxBdt40V489PoWyccvQ4Jn6ow"',
#    'id': 'vVTV9Ivyzs0',
#    'statistics': {'viewCount': '894933',
#     'likeCount': '9473',
#     'dislikeCount': '1078',
#     'favoriteCount': '0',
#     'commentCount': '656'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JO6woqP9IirSQiTWdTUWuH1AXEU"',
#    'id': 'jjIft-Ne8qo',
#    'statistics': {'viewCount': '650331',
#     'likeCount': '9110',
#     'dislikeCount': '816',
#     'favoriteCount': '0',
#     'commentCount': '771'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JvxZ_HyrHbT_GocOLzyW6yntU8g"',
#    'id': 'sxskHmh1RfQ',
#    'statistics': {'viewCount': '418612',
#     'likeCount': '6178',
#     'dislikeCount': '691',
#     'favoriteCount': '0',
#     'commentCount': '588'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ayrfVDOVssH5WqtpLvCv2rD2ttQ"',
#    'id': 'sA3fQJqzFFA',
#    'statistics': {'viewCount': '17805497',
#     'likeCount': '158096',
#     'dislikeCount': '23126',
#     'favoriteCount': '0',
#     'commentCount': '6418'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_iI9XPbz-PpUiiSvqtANBB5wuFU"',
#    'id': 'hWO0PdDVFnc',
#    'statistics': {'viewCount': '300848',
#     'likeCount': '4121',
#     'dislikeCount': '390',
#     'favoriteCount': '0',
#     'commentCount': '338'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IICuDicxPkSNvWXk4g14QWjzrHk"',
#    'id': 'KJb6xZSlUOo',
#    'statistics': {'viewCount': '812868',
#     'likeCount': '10295',
#     'dislikeCount': '1008',
#     'favoriteCount': '0',
#     'commentCount': '1191'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0leHj8LmMFKDaLubAPPqIsfsc60"',
#    'id': '5OjwCxYNwNE',
#    'statistics': {'viewCount': '385347',
#     'likeCount': '6012',
#     'dislikeCount': '575',
#     'favoriteCount': '0',
#     'commentCount': '567'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yf7bBxtaw3a3fMHTm5rppKY0k4A"',
#    'id': 'I0FbWX5VDKQ',
#    'statistics': {'viewCount': '721077',
#     'likeCount': '9875',
#     'dislikeCount': '1288',
#     'favoriteCount': '0',
#     'commentCount': '557'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ByjZYXaiv2CPShTE6S6SQnKT8MA"',
#    'id': 'HSNQ7Z3pnWE',
#    'statistics': {'viewCount': '7701069',
#     'likeCount': '75369',
#     'dislikeCount': '9870',
#     'favoriteCount': '0',
#     'commentCount': '3309'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-GG9LD3BYd8ZuK65WE8YpoXJlVI"',
#    'id': 'ufRzpmMcLTU',
#    'statistics': {'viewCount': '311554',
#     'likeCount': '5056',
#     'dislikeCount': '521',
#     'favoriteCount': '0',
#     'commentCount': '509'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Qvf_UqgnffpxmSrBTxcBy-xHA8M"',
#    'id': 'L0YSd86WqDU',
#    'statistics': {'viewCount': '7329300',
#     'likeCount': '67698',
#     'dislikeCount': '7977',
#     'favoriteCount': '0',
#     'commentCount': '3268'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7TOL250AAghLpPFPHY7BHHcN8bM"',
#    'id': 'PRtPStbFlAM',
#    'statistics': {'viewCount': '1408456',
#     'likeCount': '13651',
#     'dislikeCount': '1536',
#     'favoriteCount': '0',
#     'commentCount': '773'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/WyDs_HzfdNPMa6-1u0piKr8wLeU"',
#    'id': 'HEvIRq2aaMw',
#    'statistics': {'viewCount': '370924',
#     'likeCount': '5547',
#     'dislikeCount': '455',
#     'favoriteCount': '0',
#     'commentCount': '345'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/rqSfm75tiLg_TUQaHzRjtKqiprM"',
#    'id': 'Rfj_2e491Lg',
#    'statistics': {'viewCount': '295666',
#     'likeCount': '4634',
#     'dislikeCount': '430',
#     'favoriteCount': '0',
#     'commentCount': '452'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nWvyjKcjzJlEIawGiqs4FFOMHW8"',
#    'id': 'UJyyix4mQPs',
#    'statistics': {'viewCount': '1793386',
#     'likeCount': '15661',
#     'dislikeCount': '1656',
#     'favoriteCount': '0',
#     'commentCount': '835'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/wqNaFlBtSEETj4CjOPQtFfQMZC8"',
#    'id': 'OY_FPNytnBU',
#    'statistics': {'viewCount': '625114',
#     'likeCount': '14815',
#     'dislikeCount': '1268',
#     'favoriteCount': '0',
#     'commentCount': '1497'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Jw9_rsvT0Nc0Abs4EzWgeSfkoG4"',
#    'id': '05mY3TKPS50',
#    'statistics': {'viewCount': '428153',
#     'likeCount': '8276',
#     'dislikeCount': '586',
#     'favoriteCount': '0',
#     'commentCount': '552'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/REawCoPMkf3PgF_yTBYyEL94NcU"',
#    'id': '-HOfYxwLd1A',
#    'statistics': {'viewCount': '656734',
#     'likeCount': '7032',
#     'dislikeCount': '890',
#     'favoriteCount': '0',
#     'commentCount': '565'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oNiHLX8WgF3r9Wg63rWqqxzo41Q"',
#    'id': 'BA5wfjds1Sg',
#    'statistics': {'viewCount': '1330058',
#     'likeCount': '12765',
#     'dislikeCount': '1370',
#     'favoriteCount': '0',
#     'commentCount': '673'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/L8vtcZCh2xmBl-GOUj-eMx6znmc"',
#    'id': '8X21GPSd46I',
#    'statistics': {'viewCount': '452608',
#     'likeCount': '6400',
#     'dislikeCount': '597',
#     'favoriteCount': '0',
#     'commentCount': '505'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JEl3rCbiRl-ArEXG2lvE8C82sbQ"',
#    'id': 's3w7VxkzORo',
#    'statistics': {'viewCount': '7558406',
#     'likeCount': '49040',
#     'dislikeCount': '7627',
#     'favoriteCount': '0',
#     'commentCount': '2680'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/kXIoHUD7scsfPNkrivc9AR1I-FA"',
#    'id': 'Fj7tgwpZTso',
#    'statistics': {'viewCount': '1075985',
#     'likeCount': '13687',
#     'dislikeCount': '1461',
#     'favoriteCount': '0',
#     'commentCount': '1145'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/266fIYfgZ99vMqXQPnK-Ctswmpc"',
#    'id': 'Fl3hejyqgA8',
#    'statistics': {'viewCount': '2724356',
#     'likeCount': '19326',
#     'dislikeCount': '2062',
#     'favoriteCount': '0',
#     'commentCount': '985'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nivUxwNTMMFVks6fr4-iiHfJzrc"',
#    'id': 'G6eVlcWT43I',
#    'statistics': {'viewCount': '276450',
#     'likeCount': '3941',
#     'dislikeCount': '427',
#     'favoriteCount': '0',
#     'commentCount': '404'}}],
#  [{'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/UU3r1NTsmFzmS3-3BpIDOKGB4vk"',
#    'id': '2J_InZS4WqQ',
#    'statistics': {'viewCount': '4725129',
#     'likeCount': '56845',
#     'dislikeCount': '5025',
#     'favoriteCount': '0',
#     'commentCount': '1873'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Bw_A3BahTl66fR3M5df79ZOE3t0"',
#    'id': '792NZT3S4Lo',
#    'statistics': {'viewCount': '404661',
#     'likeCount': '6495',
#     'dislikeCount': '662',
#     'favoriteCount': '0',
#     'commentCount': '787'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/VIlrXScaT8sJbd20GQ_M4zrTRdI"',
#    'id': 'Vpa2CCBt7-I',
#    'statistics': {'viewCount': '770707',
#     'likeCount': '7403',
#     'dislikeCount': '973',
#     'favoriteCount': '0',
#     'commentCount': '488'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/IQWG48x1dv7G7AcAMWJrrYWDHWQ"',
#    'id': 'VVSAFUAmh_g',
#    'statistics': {'viewCount': '8234671',
#     'likeCount': '58967',
#     'dislikeCount': '8894',
#     'favoriteCount': '0',
#     'commentCount': '1892'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/j19XwCgCzugdqGgd815X5apQALI"',
#    'id': 'ulci9svDvEg',
#    'statistics': {'viewCount': '728347',
#     'likeCount': '9569',
#     'dislikeCount': '933',
#     'favoriteCount': '0',
#     'commentCount': '1009'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JsrdCfholpnkvndX-y4DwL6AxB4"',
#    'id': 'NxaCyoXxePk',
#    'statistics': {'viewCount': '11489810',
#     'likeCount': '60325',
#     'dislikeCount': '9714',
#     'favoriteCount': '0',
#     'commentCount': '1695'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/XnqG6LCXzcMOa-61akwQ8OO5vDU"',
#    'id': 'W-ojCzm_PNs',
#    'statistics': {'viewCount': '358064',
#     'likeCount': '4915',
#     'dislikeCount': '455',
#     'favoriteCount': '0',
#     'commentCount': '511'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/YB1p_96ADL3Pw1B6vlvQsjjcdBE"',
#    'id': '3jcKktdXytY',
#    'statistics': {'viewCount': '368933',
#     'likeCount': '8004',
#     'dislikeCount': '576',
#     'favoriteCount': '0',
#     'commentCount': '752'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/J4_r_b3mvyL5poC9aaAsCds0few"',
#    'id': 'SFG84T7oM_0',
#    'statistics': {'viewCount': '7627670',
#     'likeCount': '71471',
#     'dislikeCount': '7555',
#     'favoriteCount': '0',
#     'commentCount': '2403'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/DTj8uLHwlQy47hB359vduwmVOHk"',
#    'id': 'v3Gf2nbE444',
#    'statistics': {'viewCount': '3795252',
#     'likeCount': '33083',
#     'dislikeCount': '4729',
#     'favoriteCount': '0',
#     'commentCount': '1729'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/QGHA5lyOrJcYud5ry51tU_AxGjU"',
#    'id': 'HQHK-wK4RSY',
#    'statistics': {'viewCount': '1511612',
#     'likeCount': '18664',
#     'dislikeCount': '2099',
#     'favoriteCount': '0',
#     'commentCount': '1238'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/tzMXWCTyozifI8UJd1GeHNnQQXc"',
#    'id': 'JAFTFfcqln0',
#    'statistics': {'viewCount': '1586188',
#     'likeCount': '14153',
#     'dislikeCount': '1882',
#     'favoriteCount': '0',
#     'commentCount': '903'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2oHUri9EmjFKobXKF8YU2ttiO3s"',
#    'id': 'JVX5gCYnhdk',
#    'statistics': {'viewCount': '3630279',
#     'likeCount': '22918',
#     'dislikeCount': '3748',
#     'favoriteCount': '0',
#     'commentCount': '1352'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fdXEXh9pQ6lTAr7VC2PpoE_HbdU"',
#    'id': 'gY3IekYSSXY',
#    'statistics': {'viewCount': '621450',
#     'likeCount': '7769',
#     'dislikeCount': '846',
#     'favoriteCount': '0',
#     'commentCount': '600'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-HPWGZ5RBwa72mao-D5YSPqmuUE"',
#    'id': 'k59MxZJEtIg',
#    'statistics': {'viewCount': '6899067',
#     'likeCount': '52341',
#     'dislikeCount': '7704',
#     'favoriteCount': '0',
#     'commentCount': '2694'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/zYONxelF8Vx0-p9UuQPdBvdaqp4"',
#    'id': 'Z2qLa1x22YQ',
#    'statistics': {'viewCount': '339671',
#     'likeCount': '5699',
#     'dislikeCount': '520',
#     'favoriteCount': '0',
#     'commentCount': '742'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/G5kYpLgP351cZk098tGw_R_NVLo"',
#    'id': '8-Ml2F8wO00',
#    'statistics': {'viewCount': '11295976',
#     'likeCount': '83063',
#     'dislikeCount': '13670',
#     'favoriteCount': '0',
#     'commentCount': '5416'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/X07aISniOuU_qeVPm_YWY-vgA4k"',
#    'id': 'xB1dWa-L7Mo',
#    'statistics': {'viewCount': '2985921',
#     'likeCount': '35521',
#     'dislikeCount': '3546',
#     'favoriteCount': '0',
#     'commentCount': '2199'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_kL7cifSMxpNvLz2DPpeVXYXudM"',
#    'id': 'Xwsp8Z2LOTE',
#    'statistics': {'viewCount': '541924',
#     'likeCount': '6315',
#     'dislikeCount': '747',
#     'favoriteCount': '0',
#     'commentCount': '606'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/RY8LrO2PcAOi3htF-tRYLEgqo1s"',
#    'id': 'lLJt4tYOTSk',
#    'statistics': {'viewCount': '2716029',
#     'likeCount': '22124',
#     'dislikeCount': '2187',
#     'favoriteCount': '0',
#     'commentCount': '854'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/_70jhgzl0stfuLpAlGVsMX67vng"',
#    'id': 'eWU7z6drQps',
#    'statistics': {'viewCount': '1735695',
#     'likeCount': '23805',
#     'dislikeCount': '2317',
#     'favoriteCount': '0',
#     'commentCount': '1333'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7zqCBoZYL-R3iyKwzvmnfKDu6NQ"',
#    'id': '1SP3gBXNYvI',
#    'statistics': {'viewCount': '814727',
#     'likeCount': '10357',
#     'dislikeCount': '890',
#     'favoriteCount': '0',
#     'commentCount': '864'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/MaBwPiuwwtHqFc06_a_eXUj8nig"',
#    'id': 'zbNxejtap_o',
#    'statistics': {'viewCount': '540631',
#     'likeCount': '7161',
#     'dislikeCount': '673',
#     'favoriteCount': '0',
#     'commentCount': '672'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7ann6IKNr7iNYHe6kRU71ktKVkY"',
#    'id': 'zQmkYIMHgnw',
#    'statistics': {'viewCount': '326468',
#     'likeCount': '4309',
#     'dislikeCount': '437',
#     'favoriteCount': '0',
#     'commentCount': '443'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TY5aKc6upeJIo5LFU74pVNY7TUk"',
#    'id': 'ydmfufcojBo',
#    'statistics': {'viewCount': '465534',
#     'likeCount': '4048',
#     'dislikeCount': '474',
#     'favoriteCount': '0',
#     'commentCount': '312'}},
#   {'kind': 'youtube#video',
# ...
#    'id': 'f8_7J8tIyXs',
#    'statistics': {'viewCount': '222144',
#     'likeCount': '101',
#     'dislikeCount': '4',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3tcbZToBCBAmpA39N5hmob85zlk"',
#    'id': 'pzCMOjFQEBY',
#    'statistics': {'viewCount': '3446',
#     'likeCount': '55',
#     'dislikeCount': '4',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/s9IL4H4whqfLZvy2xXggDRf5ihI"',
#    'id': 'RsQaojbgeY0',
#    'statistics': {'viewCount': '14882',
#     'likeCount': '130',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '8'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/nO_oii9IEtRAbbc-uNQh9Gzm_ac"',
#    'id': 'm7rc3FGVdmo',
#    'statistics': {'viewCount': '37229',
#     'likeCount': '238',
#     'dislikeCount': '16',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/KyyQJrOAVMrIxj6Tu_MYZRmJC_g"',
#    'id': 'tIEc2_vBRiA',
#    'statistics': {'viewCount': '32522',
#     'likeCount': '177',
#     'dislikeCount': '9',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Ru3VziSX4GMgjYVwfJxAPDDFlmc"',
#    'id': 'jBDbl84ZbhU',
#    'statistics': {'viewCount': '5225',
#     'likeCount': '71',
#     'dislikeCount': '3',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/oxygmjmchMLWTRQVvfVnKZVInNE"',
#    'id': 'rqtykuVghzg',
#    'statistics': {'viewCount': '6909',
#     'likeCount': '90',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/88E45Dj4a1keGEEC8ocM8tZem_E"',
#    'id': '0C_1VdPlIuI',
#    'statistics': {'viewCount': '16560',
#     'likeCount': '107',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/qwpsPprgu5oaT4suZ5urtzgOCbQ"',
#    'id': 'BmkKvD491Oo',
#    'statistics': {'viewCount': '27203',
#     'likeCount': '113',
#     'dislikeCount': '11',
#     'favoriteCount': '0',
#     'commentCount': '5'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vUkr_xndF5FD5nZLvbUQ9XRXbT4"',
#    'id': 'YAh9NE0q5vA',
#    'statistics': {'viewCount': '6616',
#     'likeCount': '87',
#     'dislikeCount': '5',
#     'favoriteCount': '0',
#     'commentCount': '0'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TIRMLX86SeWpU95ZH-0AQJBix1k"',
#    'id': '8jiA3rdr3Hk',
#    'statistics': {'viewCount': '199296',
#     'likeCount': '1639',
#     'dislikeCount': '77',
#     'favoriteCount': '0',
#     'commentCount': '70'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ehN1PQ-VgHhooo9ttmx5wH-6BKY"',
#    'id': '3w66yyWnyEY',
#    'statistics': {'viewCount': '203616',
#     'likeCount': '2994',
#     'dislikeCount': '93',
#     'favoriteCount': '0',
#     'commentCount': '60'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/4BY4Koge3Jjqi1mjXbd1Ahq_1_4"',
#    'id': 'iJjxPva8-jk',
#    'statistics': {'viewCount': '27447',
#     'likeCount': '259',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '5'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/iEmmeXnl9miYK8QfQaKNt-MZnPA"',
#    'id': 'lWHG7rA5k4Y',
#    'statistics': {'viewCount': '6945',
#     'likeCount': '98',
#     'dislikeCount': '11',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/P8sCWhxqwAvuy7A42wuxaiR3hlQ"',
#    'id': 'JejdEZZIT0s',
#    'statistics': {'viewCount': '23673',
#     'likeCount': '262',
#     'dislikeCount': '28',
#     'favoriteCount': '0',
#     'commentCount': '31'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/n9JJHOkPuX6yiWV74rESlHO4hfA"',
#    'id': '5wGcuE7IHGE',
#    'statistics': {'viewCount': '49851',
#     'likeCount': '216',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '8'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LTz23DUvyH_Y9QzgaytGlJjNGnA"',
#    'id': 'nubR9WIi1b8',
#    'statistics': {'viewCount': '87167',
#     'likeCount': '377',
#     'dislikeCount': '20',
#     'favoriteCount': '0',
#     'commentCount': '20'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/GKag59645NObQVC-k6UEjZFdlX8"',
#    'id': 'NjKryFh1pZc',
#    'statistics': {'viewCount': '111495',
#     'likeCount': '350',
#     'dislikeCount': '19',
#     'favoriteCount': '0',
#     'commentCount': '23'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Qr_qgnwjRBd3NR4TFrpepYbttnA"',
#    'id': 'X8K41dQbWV4',
#    'statistics': {'viewCount': '38763',
#     'likeCount': '149',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '2'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0CtWRN7l21H_nxuB_vJrQlz2x7c"',
#    'id': 'ELn0OjxflX8',
#    'statistics': {'viewCount': '53279',
#     'likeCount': '599',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '21'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/g3CfPDNff3nyBPAp3Aclw3z3wEw"',
#    'id': 'YjIo5NKDzhE',
#    'statistics': {'viewCount': '253126',
#     'likeCount': '1771',
#     'dislikeCount': '219',
#     'favoriteCount': '0',
#     'commentCount': '58'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OC7z-5c0b6wQ1i2qpmtpip9q0Ng"',
#    'id': 'drsGdR9YbsU',
#    'statistics': {'viewCount': '74321',
#     'likeCount': '997',
#     'dislikeCount': '30',
#     'favoriteCount': '0',
#     'commentCount': '66'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/SQXvHYTerkmILggNGTkkS9hxgvY"',
#    'id': 'fa8AmzpIjGc',
#    'statistics': {'viewCount': '48826',
#     'likeCount': '447',
#     'dislikeCount': '22',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/UYabPKTadEnFI1HKszWK_vYREaI"',
#    'id': 'yZfNIBRNEew',
#    'statistics': {'viewCount': '61686',
#     'likeCount': '445',
#     'dislikeCount': '35',
#     'favoriteCount': '0',
#     'commentCount': '20'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/-29FsrlFgqYMRG7cmlKp7rmhYuk"',
#    'id': 'lRfuTCWUTEQ',
#    'statistics': {'viewCount': '54217',
#     'likeCount': '396',
#     'dislikeCount': '29',
#     'favoriteCount': '0',
#     'commentCount': '13'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/htYWdsrAsnwgYIYGFpLs6swJ3iM"',
#    'id': 'frDRWmtcw5A',
#    'statistics': {'viewCount': '56074',
#     'likeCount': '226',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fTymREvuYsT24QF0S94VRQblu6M"',
#    'id': 'U_ZobLRm4KI',
#    'statistics': {'viewCount': '127220',
#     'likeCount': '274',
#     'dislikeCount': '33',
#     'favoriteCount': '0',
#     'commentCount': '13'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/DPUGlfVvcKvZ_L9oDkkKakGnRm0"',
#    'id': 'znManE9_Xk4',
#    'statistics': {'viewCount': '45942',
#     'likeCount': '217',
#     'dislikeCount': '13',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/l8MtQuF6it_XksH2cVBo3rR5DIg"',
#    'id': 'B3wXxTTvuIo',
#    'statistics': {'viewCount': '202212',
#     'likeCount': '694',
#     'dislikeCount': '125',
#     'favoriteCount': '0',
#     'commentCount': '24'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/Mpe9YeQfabJ2y8Q62od2LG41Hcs"',
#    'id': 'l9d0b5h04G8',
#    'statistics': {'viewCount': '51324',
#     'likeCount': '301',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '11'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/cGVBourZqLs_4oaNvkWRR-lXGqo"',
#    'id': 'iH3HG5btxa0',
#    'statistics': {'viewCount': '102067',
#     'likeCount': '637',
#     'dislikeCount': '23',
#     'favoriteCount': '0',
#     'commentCount': '16'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/yTSHDAP4K-LGb4IXHwFxgH8WlzM"',
#    'id': '3SenuDBI5lM',
#    'statistics': {'viewCount': '71592',
#     'likeCount': '261',
#     'dislikeCount': '16',
#     'favoriteCount': '0',
#     'commentCount': '20'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/GBL_tT3uIpc5IsXOEUMsJqDgf6E"',
#    'id': '56FY7M7Hxa0',
#    'statistics': {'viewCount': '25830',
#     'likeCount': '174',
#     'dislikeCount': '8',
#     'favoriteCount': '0',
#     'commentCount': '1'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/72bwWI903sv2rBoTRsfV8WupTwY"',
#    'id': 'bkGsXmUOiR4',
#    'statistics': {'viewCount': '39551',
#     'likeCount': '203',
#     'dislikeCount': '9',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ZoWZ99Y49utBXAAgZnLZXPx9zX0"',
#    'id': 's5QLlGy1Fac',
#    'statistics': {'viewCount': '48545',
#     'likeCount': '400',
#     'dislikeCount': '15',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/NdvcM7CMzrwUiBeKVeBf1goYuaA"',
#    'id': 'uJh4UJlUMV8',
#    'statistics': {'viewCount': '37308',
#     'likeCount': '230',
#     'dislikeCount': '11',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/EuoqLLpYp4njTqPymoeiVSjntjY"',
#    'id': 'lqgbsSNBK9A',
#    'statistics': {'viewCount': '7050',
#     'likeCount': '157',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '5'}}],
#  [{'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/YZNtTpdxOi77JG5Q4Gdg_IOnp2U"',
#    'id': 'n-vH-llJeHg',
#    'statistics': {'viewCount': '25105',
#     'likeCount': '157',
#     'dislikeCount': '5',
#     'favoriteCount': '0',
#     'commentCount': '5'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/KWmpLjhAobw-klUgtRFvBVqg_w0"',
#    'id': 'UhXnkJtnaus',
#    'statistics': {'viewCount': '30887',
#     'likeCount': '214',
#     'dislikeCount': '3',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/fGXu27zg9tR9tDBz3TzVVAD8WAA"',
#    'id': '-5Et17hz_DM',
#    'statistics': {'viewCount': '46774',
#     'likeCount': '273',
#     'dislikeCount': '5',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/D74rzH1BnSJZvc-usJMCt8MsjdM"',
#    'id': 'wypu5r9VmNY',
#    'statistics': {'viewCount': '21941',
#     'likeCount': '190',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '3'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LnBkC5Zsh0ufSjFWYtlbZpLorBg"',
#    'id': 'ac6asfwdQls',
#    'statistics': {'viewCount': '258483',
#     'likeCount': '1689',
#     'dislikeCount': '80',
#     'favoriteCount': '0',
#     'commentCount': '74'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/0kh7e4cIizsOvJs3TwBYBZ0vszc"',
#    'id': 'PsgI8GbZ5eM',
#    'statistics': {'viewCount': '28031',
#     'likeCount': '245',
#     'dislikeCount': '7',
#     'favoriteCount': '0',
#     'commentCount': '6'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/2KRxVe6EbnAFacrh7r8NJhIoFbU"',
#    'id': 'IIOBFdNog4g',
#    'statistics': {'viewCount': '61471',
#     'likeCount': '431',
#     'dislikeCount': '20',
#     'favoriteCount': '0',
#     'commentCount': '11'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/hY_UPuhAHzL-VzL7GWNzFtKTi68"',
#    'id': 'KyWaUJzg-Rg',
#    'statistics': {'viewCount': '28762',
#     'likeCount': '312',
#     'dislikeCount': '12',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/7OYmeFUDZmrU9OxJqACLXyGk_QM"',
#    'id': 'WqBGf6cCNTg',
#    'statistics': {'viewCount': '33105',
#     'likeCount': '262',
#     'dislikeCount': '16',
#     'favoriteCount': '0',
#     'commentCount': '8'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/aMRQGdDY-Nj3akpEaIauQfkz5VE"',
#    'id': 'BLAOxrGNaMI',
#    'statistics': {'viewCount': '47394',
#     'likeCount': '247',
#     'dislikeCount': '16',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/UfXkkcxcyYM8JxCAz517MRhuHnY"',
#    'id': 'czM9HXlcQCM',
#    'statistics': {'viewCount': '21414',
#     'likeCount': '236',
#     'dislikeCount': '10',
#     'favoriteCount': '0',
#     'commentCount': '7'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/JoiPPTKL3gec8YqbApaqqg2S8AA"',
#    'id': 'jGS1oSNxC9w',
#    'statistics': {'viewCount': '38869',
#     'likeCount': '310',
#     'dislikeCount': '12',
#     'favoriteCount': '0',
#     'commentCount': '13'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/ZUa0vAJEbEt9JbgElytjKhO8Mik"',
#    'id': 'tL42e-U69jo',
#    'statistics': {'viewCount': '214195',
#     'likeCount': '2842',
#     'dislikeCount': '202',
#     'favoriteCount': '0',
#     'commentCount': '270'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/o2a4ITL1X3P0aCxExCTa0cH-I1U"',
#    'id': 'cHpVrAAS67g',
#    'statistics': {'viewCount': '112815',
#     'likeCount': '666',
#     'dislikeCount': '33',
#     'favoriteCount': '0',
#     'commentCount': '30'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/TP3REqy66Phe6QzWY5vWfXTfCZc"',
#    'id': 'x_wi_XTdmcE',
#    'statistics': {'viewCount': '34789',
#     'likeCount': '344',
#     'dislikeCount': '18',
#     'favoriteCount': '0',
#     'commentCount': '15'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/LIGzSigBixFW4dbZEVHLNUcrnDo"',
#    'id': 'X1upW_OKzvg',
#    'statistics': {'viewCount': '47705',
#     'likeCount': '537',
#     'dislikeCount': '26',
#     'favoriteCount': '0',
#     'commentCount': '14'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/tqjcC6sF7TO2d-PcCdaaVXO7X7I"',
#    'id': 'qKu5uwkstOc',
#    'statistics': {'viewCount': '23335',
#     'likeCount': '268',
#     'dislikeCount': '20',
#     'favoriteCount': '0',
#     'commentCount': '11'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/4bLXP-YWIxzAcDiaEaaBLFMJAys"',
#    'id': 'JzVRhpemgU4',
#    'statistics': {'viewCount': '131099',
#     'likeCount': '1268',
#     'dislikeCount': '50',
#     'favoriteCount': '0',
#     'commentCount': '33'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/xqjDb5g0GBWVTLElcoIQ7srxe5U"',
#    'id': 'RA9GjoRhcSE',
#    'statistics': {'viewCount': '53674',
#     'likeCount': '528',
#     'dislikeCount': '37',
#     'favoriteCount': '0',
#     'commentCount': '18'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/v9qjMTSYRrupLUoW_sfg1632JGc"',
#    'id': 'KtetRv4kfog',
#    'statistics': {'viewCount': '40307',
#     'likeCount': '661',
#     'dislikeCount': '28',
#     'favoriteCount': '0',
#     'commentCount': '17'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/4_RbJ48xqW43wnOXxuAQaXpMPxo"',
#    'id': 'AEp338eSyDM',
#    'statistics': {'viewCount': '56723',
#     'likeCount': '845',
#     'dislikeCount': '28',
#     'favoriteCount': '0',
#     'commentCount': '36'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/eIk8V2wNZjAKppBxQmThnW1PGxk"',
#    'id': 'JmFQavE0sPM',
#    'statistics': {'viewCount': '43632',
#     'likeCount': '655',
#     'dislikeCount': '26',
#     'favoriteCount': '0',
#     'commentCount': '30'}},
#   {'kind': 'youtube#video',
#    'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/vw2t7RqfLBIzlf6YW7TDXJOMsvo"',
#    'id': 's_99ugf_diM',
#    'statistics': {'viewCount': '42794',
#     'likeCount': '815',
#     'dislikeCount': '52',
#     'favoriteCount': '0',
#     'commentCount': '155'}}]]
